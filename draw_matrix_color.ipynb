# %% [markdown]
# <a href="https://colab.research.google.com/github/B0544218/thesis/blob/main/draw_matrix_color.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np

data = [['x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '1', 'x', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['0', '0', '1', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '0', '1', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '1', 'x', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['0', '0', '1', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '0', '1', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '1', 'x', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['0', '0', '1', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '0', '1', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '1', 'x', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['0', '0', '1', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '0', '1', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '1', 'x', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['0', '0', '1', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',],
      ['x', '0', '1', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0','x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0', 'x', '1', '0', '1', 'x', '0', '1', 'x', '0', '1', 'x', '0',]]
data = np.array(data)
unique_chars, matrix = np.unique(data, return_inverse=True)
color_dict = {'x': 'darkred', '1': 'white', '0': 'orange'}
plt.matshow(matrix.reshape(data.shape), cmap=ListedColormap([color_dict[char] for char in unique_chars]))
plt.xticks(np.arange(data.shape[1]), np.arange(data.shape[1]) + 1)
plt.yticks(np.arange(data.shape[0]), np.arange(data.shape[0]) + 1)
# Set ticks on both sides of axes on
plt.tick_params(axis="x", bottom=True, top=False, labelbottom=True, labeltop=False)
plt.ylabel('BookRoll \n Learning Strategy', fontsize = 15) # y-axis label with fontsize 15
plt.show()

# %% [markdown]
# ## BookRoll

# %% [markdown]
# ### draw event per week

# %%
# !gdown 1ZXE0Kdoeecc-qZrNLWqMWwwStRlv5SZn
import pandas as pd
df = pd.read_csv("LBLS_seqs_input_data.csv")
df = df.fillna('')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZXE0Kdoeecc-qZrNLWqMWwwStRlv5SZn
# To: /content/LBLS_seqs_input_data.csv
# 100% 3.48M/3.48M [00:00<00:00, 105MB/s]
# ...

# %%
def br_strategy_calculate(df, strategy_class):
  print('bookroll class '+ str(strategy_class))
  df_tmp = df[df['class'] == strategy_class]
  df_tmp = df_tmp.drop(columns=['class'])
  df_tmp = df_tmp.reset_index(drop=True)
  df_tmp['Reading'] = 0
  df_tmp['Highlight'] = 0
  df_tmp['Notetaking'] = 0

  from collections import Counter
  # 統計seuqnce中行為
  for index, row in df_tmp.iterrows():
    values = Counter(row[2:])
    df_tmp.at[index, 'Reading'] = values['Reading']
    df_tmp.at[index, 'Highlight'] = values['Highligt']
    df_tmp.at[index, 'Notetaking'] = values['Notetaking']

  df_tmp = df_tmp[['username', 'weeks', 'Reading', 'Highlight', 'Notetaking']]


  # 由於有些learning strategy中少了學生部分行為週次的資料(也許他沒做，也許在另外一個strategy)，因此這邊補0
  for user in set(df_tmp['username']):
    for w in range(1,17):
      # 該週學生沒有learning strategy的行為就補0
      if w not in set(df_tmp[df_tmp['username'] == user]['weeks']):
        # 這裡邏輯好像有錯誤
        data = pd.DataFrame([[user, w, 0, 0, 0]], columns=["username", "weeks", "Reading", "Highlight", "Notetaking"])
        df_tmp = pd.concat([df_tmp, data], ignore_index=True)
  df_tmp = df_tmp.sort_values(by=['username', 'weeks'])
  df_tmp = df_tmp.reset_index(drop=True)

  # bookroll0 reading、highlight、notetaking initialize
  reading = pd.DataFrame(columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"])
  highlight = pd.DataFrame(columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"])
  notetaking = pd.DataFrame(columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"])

  for user in set(df_tmp['username']):
    # data
    reading_data = []
    highlight_data = []
    notetaking_data = []
    reading_data.append(str(user))
    highlight_data.append(str(user))
    notetaking_data.append(str(user))
    for w in range(1,17):
      tmp = df_tmp[(df_tmp['username'] == user) & (df_tmp['weeks'] == w)]
      reading_data.append(tmp['Reading'].iloc[0])
      highlight_data.append(tmp['Highlight'].iloc[0])
      notetaking_data.append(tmp['Notetaking'].iloc[0])

    # 將data放入dataframe
    reading = pd.concat([reading, pd.DataFrame([reading_data], columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"]) ])
    highlight = pd.concat([highlight, pd.DataFrame([highlight_data], columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"]) ])
    notetaking = pd.concat([notetaking, pd.DataFrame([notetaking_data], columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"]) ])

  # 分組序列reading，從中找代表序列，並算出代表序列的次數
  from sklearn.cluster import KMeans
  from collections import Counter
  kmeans = KMeans(n_clusters=5).fit(reading.iloc[:,1:])
  centroids = kmeans.cluster_centers_
  predict = kmeans.predict(reading.iloc[:,1:])

  reading['cluster'] = predict
  # reading1.iloc[:,1:].head()
  # 之後要做mean，這邊把0作為nan讓他不會計算mean的時候考慮進去
  # reading = reading.replace(0, np.nan)
  group_count = reading['cluster'].value_counts()
  reading = reading.groupby(['cluster']).mean()
  reading['count'] = group_count.sort_index()


  # 分組序列highlight，從中找代表序列，並算出代表序列的次數
  from sklearn.cluster import KMeans
  from collections import Counter
  kmeans = KMeans(n_clusters=5).fit(highlight.iloc[:,1:])
  centroids = kmeans.cluster_centers_
  predict = kmeans.predict(highlight.iloc[:,1:])

  highlight['cluster'] = predict
  # reading1.iloc[:,1:].head()
  # 之後要做mean，這邊把0作為nan讓他不會計算mean的時候考慮進去
  # highlight = highlight.replace(0, np.nan)
  group_count = highlight['cluster'].value_counts()
  highlight = highlight.groupby(['cluster']).mean()
  highlight['count'] = group_count.sort_index()



  # 分組序列notetaking，從中找代表序列，並算出代表序列的次數
  from sklearn.cluster import KMeans
  from collections import Counter
  kmeans = KMeans(n_clusters=5).fit(notetaking.iloc[:,1:])
  centroids = kmeans.cluster_centers_
  predict = kmeans.predict(notetaking.iloc[:,1:])
  notetaking['cluster'] = predict
  # reading1.iloc[:,1:].head()
  # 之後要做mean，這邊把0作為nan讓他不會計算mean的時候考慮進去
  # notetaking = notetaking.replace(0, np.nan)
  group_count = notetaking['cluster'].value_counts()
  notetaking = notetaking.groupby(['cluster']).mean()
  notetaking['count'] = group_count.sort_index()

  return reading, highlight, notetaking

# %%
reading0, highlight0, notetaking0 = br_strategy_calculate(df, 0)
reading0 = reading0.sort_values(['count'])
highlight0 = highlight0.sort_values(['count'])
notetaking0 = notetaking0.sort_values(['count'])
# Out:
# bookroll class 0
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
reading1, highlight1, notetaking1 = br_strategy_calculate(df, 1)
reading1 = reading1.sort_values(['count'])
highlight1 = highlight1.sort_values(['count'])
notetaking1 = notetaking1.sort_values(['count'])
# Out:
# bookroll class 1
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
reading0.iloc[:, 1:]
# Out:
#            weeks1    weeks2    weeks3    weeks4    weeks5    weeks6    weeks7  \
# cluster
# 2        0.814815  1.000000  1.111111  2.500000  6.444444  2.111111  2.018519
# 3        1.600000  1.883333  6.416667  1.550000  0.983333  2.100000  1.933333
# 4        1.416667  0.616667  0.316667  1.633333  0.633333  2.500000  0.966667
# 1        0.830769  0.738462  0.830769  1.200000  1.015385  1.153846  6.123077
# 0        0.638009  0.805430  0.339367  0.927602  0.542986  0.742081  0.619910
#
#            weeks8    weeks9   weeks10   weeks11   weeks12   weeks13   weeks14  \
# cluster
# 2        2.037037  2.370370  1.592593  1.148148  1.166667  1.777778  1.870370
# 3        1.383333  1.550000  0.950000  1.716667  1.966667  1.483333  1.466667
# 4        6.050000  2.866667  0.983333  1.700000  1.500000  1.916667  2.183333
# 1        2.261538  1.076923  1.153846  1.476923  1.538462  1.830769  1.184615
# 0        0.520362  1.027149  0.846154  1.031674  0.737557  0.932127  0.886878
#
# ...

# %%
reading1.iloc[:, 1: -1]
# Out:
#             weeks1     weeks2     weeks3     weeks4     weeks5     weeks6  \
# cluster
# 4         8.428571  70.285714  75.714286  42.142857  18.571429  41.000000
# 3         4.020833  40.270833  28.812500  23.791667  14.958333  18.708333
# 0        11.350877   4.280702  24.368421  26.017544  29.298246  20.000000
# 1        46.843750  34.921875  22.953125  14.921875  16.968750  21.859375
# 2         8.701571   7.879581  11.167539   6.575916   5.575916   6.345550
#
#             weeks7     weeks8     weeks9   weeks10   weeks11    weeks12  \
# cluster
# 4        76.285714  30.714286  55.857143  3.000000  8.428571  23.428571
# 3        23.041667  10.770833   3.687500  3.750000  3.250000   4.458333
# 0        10.526316  10.421053  10.929825  5.543860  1.596491   1.122807
# 1         5.609375   6.234375   1.046875  1.468750  5.437500  10.687500
# 2         3.151832   2.251309   1.481675  0.408377  0.507853   1.382199
#
#            weeks13    weeks14   weeks15   weeks16
# cluster
# ...

# %%
highlight0.iloc[:, 1: -1]
# Out:
#            weeks1    weeks2    weeks3    weeks4    weeks5    weeks6    weeks7  \
# cluster
# 4        0.161290  0.354839  0.741935  0.129032  0.354839  0.483871  0.290323
# 3        0.305556  0.361111  0.666667  0.083333  0.222222  0.527778  0.388889
# 2        0.450000  0.375000  0.125000  0.100000  0.525000  0.575000  0.650000
# 0        0.119048  0.333333  0.857143  2.785714  1.952381  0.571429  0.452381
# 1        0.327974  0.344051  0.340836  0.109325  0.090032  0.228296  0.276527
#
#            weeks8    weeks9   weeks10   weeks11   weeks12   weeks13   weeks14  \
# cluster
# 4        0.387097  0.677419  0.580645  0.419355  0.322581  0.161290  4.225806
# 3        0.722222  0.333333  0.000000  4.111111  0.666667  0.638889  0.416667
# 2        0.650000  0.400000  0.500000  0.100000  0.875000  4.050000  0.400000
# 0        0.357143  0.619048  0.333333  0.285714  0.095238  0.309524  0.166667
# 1        0.282958  0.199357  0.135048  0.051447  0.250804  0.061093  0.077170
#
# ...

# %%
highlight1.iloc[:, 1: -1]
# Out:
#             weeks1     weeks2     weeks3     weeks4     weeks5     weeks6  \
# cluster
# 3         3.200000  32.300000  49.300000  27.700000  11.800000  22.700000
# 1        38.719298  22.508772  14.175439  10.789474  11.842105  15.245614
# 4         5.500000  28.879310  18.189655  14.724138   8.482759  11.724138
# 0         5.112676   4.140845  18.422535  13.239437  17.492958  11.464789
# 2         6.023392   5.093567   6.590643   3.807018   2.754386   3.754386
#
#             weeks7     weeks8     weeks9   weeks10   weeks11    weeks12  \
# cluster
# 3        48.800000  13.100000  27.200000  0.700000  3.800000  11.600000
# 1         2.982456   5.122807   3.122807  1.122807  4.473684   6.736842
# 4        11.517241   5.586207   1.172414  2.844828  2.206897   4.172414
# 0         6.408451   5.309859   5.633803  3.464789  1.352113   1.774648
# 2         1.847953   1.070175   0.795322  0.152047  0.385965   0.713450
#
#           weeks13    weeks14   weeks15   weeks16
# cluster
# ...

# %%
notetaking0.iloc[:, 1: -1]
# Out:
#            weeks1    weeks2    weeks3    weeks4    weeks5    weeks6    weeks7  \
# cluster
# 1        0.041667  0.541667  0.833333  0.750000  0.625000  6.333333  1.875000
# 4        0.272727  0.090909  0.242424  0.181818  0.454545  0.242424  0.181818
# 3        0.690476  1.023810  1.047619  1.142857  4.357143  0.714286  0.976190
# 2        0.312500  0.166667  1.000000  1.333333  0.166667  0.520833  4.604167
# 0        0.185304  0.246006  0.453674  0.402556  0.159744  0.230032  0.249201
#
#            weeks8    weeks9   weeks10   weeks11   weeks12   weeks13   weeks14  \
# cluster
# 1        1.666667  1.291667  0.333333  0.125000  0.416667  0.583333  0.416667
# 4        4.151515  3.545455  0.666667  0.424242  0.242424  0.303030  0.969697
# 3        0.952381  0.833333  0.142857  0.166667  0.357143  0.357143  0.404762
# 2        1.645833  0.395833  0.083333  0.375000  0.416667  0.687500  0.625000
# 0        0.300319  0.214058  0.063898  0.166134  0.115016  0.268371  0.194888
#
# ...

# %%
notetaking1.iloc[:, 1: -1]
# Out:
#             weeks1     weeks2     weeks3     weeks4     weeks5     weeks6  \
# cluster
# 1         0.714286  32.285714  32.857143  15.142857  10.714286  12.428571
# 4         9.695652  13.217391   8.304348  22.652174  18.826087  14.260870
# 3        17.120000  10.400000   9.100000   4.600000   4.480000   6.360000
# 0         1.797753   6.674157   8.168539   6.426966   6.280899   6.382022
# 2         2.409091   1.939394   2.550505   1.414141   1.535354   1.434343
#
#             weeks7     weeks8     weeks9   weeks10   weeks11    weeks12  \
# cluster
# 1        27.000000  17.000000  28.857143  1.857143  1.428571  10.142857
# 4         9.782609   4.565217   1.434783  1.826087  0.869565   0.826087
# 3         1.580000   1.920000   0.260000  0.180000  0.720000   2.460000
# 0         4.730337   3.617978   1.797753  0.741573  0.460674   0.943820
# 2         0.671717   0.681818   0.257576  0.065657  0.095960   0.222222
#
#           weeks13    weeks14   weeks15   weeks16
# cluster
# ...

# %% [markdown]
# ### 透過average去分類 高低

# %%
import numpy as np
# 將兩個學習策略的dataframe合併起來算平均
reading_all = pd.concat([ reading0.iloc[:, 1: -1], reading1.iloc[:, 1: -1] ])
reading_all = reading_all.to_numpy().flatten().astype(int)
reading_all = reading_all[reading_all != 0]
reading_all_mean = round(reading_all.mean(), 0)

highlight_all = pd.concat([ highlight0.iloc[:, 1: -1], highlight1.iloc[:, 1: -1] ])
highlight_all = highlight_all.to_numpy().flatten().astype(int)
highlight_all = highlight_all[highlight_all != 0]
highlight_all_mean = round(highlight_all.mean(), 0)

notetaking_all = pd.concat([ notetaking0.iloc[:, 1: -1], notetaking1.iloc[:, 1: -1] ])
notetaking_all = notetaking_all.to_numpy().flatten().astype(int)
notetaking_all = notetaking_all[notetaking_all != 0]
notetaking_all_mean = round(notetaking_all.mean(), 0)

# %%
notetaking0.iloc[:, 1: -1]
# Out:
#            weeks1    weeks2    weeks3    weeks4    weeks5    weeks6    weeks7  \
# cluster
# 1        0.041667  0.541667  0.833333  0.750000  0.625000  6.333333  1.875000
# 4        0.272727  0.090909  0.242424  0.181818  0.454545  0.242424  0.181818
# 3        0.690476  1.023810  1.047619  1.142857  4.357143  0.714286  0.976190
# 2        0.312500  0.166667  1.000000  1.333333  0.166667  0.520833  4.604167
# 0        0.185304  0.246006  0.453674  0.402556  0.159744  0.230032  0.249201
#
#            weeks8    weeks9   weeks10   weeks11   weeks12   weeks13   weeks14  \
# cluster
# 1        1.666667  1.291667  0.333333  0.125000  0.416667  0.583333  0.416667
# 4        4.151515  3.545455  0.666667  0.424242  0.242424  0.303030  0.969697
# 3        0.952381  0.833333  0.142857  0.166667  0.357143  0.357143  0.404762
# 2        1.645833  0.395833  0.083333  0.375000  0.416667  0.687500  0.625000
# 0        0.300319  0.214058  0.063898  0.166134  0.115016  0.268371  0.194888
#
# ...

# %%
reading0_input = reading0.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > reading_all_mean else 'low'))
highlight0_input = highlight0.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > highlight_all_mean else 'low'))
notetaking0_input = notetaking0.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > notetaking_all_mean else 'low'))

reading1_input = reading1.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < .1 else ('high' if x > reading_all_mean else 'low'))
highlight1_input = highlight1.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > highlight_all_mean else 'low'))
notetaking1_input = notetaking1.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > notetaking_all_mean else 'low'))

# %%
reading0_input = reading0_input.sort_values(["weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                    "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"])
reading0_input.head()
# Out:
#         weeks1 weeks2 weeks3 weeks4 weeks5 weeks6 weeks7 weeks8 weeks9  \
# cluster
# 0        empty  empty  empty  empty  empty  empty  empty  empty    low
# 1        empty  empty  empty    low    low    low    low    low    low
# 2        empty    low    low    low    low    low    low    low    low
# 4          low  empty  empty    low  empty    low  empty    low    low
# 3          low    low    low    low  empty    low    low    low    low
#
#         weeks10 weeks11 weeks12 weeks13 weeks14 weeks15 weeks16
# cluster
# 0         empty     low   empty   empty   empty   empty   empty
# 1           low     low     low     low     low   empty   empty
# 2           low     low     low     low     low     low     low
# 4         empty     low     low     low     low     low   empty
# 3         empty     low     low     low     low     low     low

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
import matplotlib.patches as mpatches

def draw(sequences, strategy_name, behavior, ratio):
  print(strategy_name)
  data = sequences
  data = np.array(data)
  unique_chars, matrix = np.unique(data, return_inverse=True)
  color_dict = {'empty': 'blue', 'low': 'powderblue', 'high': 'tomato'}

  # 圖片顯示大小、顏色、matrix代表資料
  plt.figure(figsize=(12,10))
  plt.matshow(matrix.reshape(data.shape), cmap=ListedColormap([color_dict[char] for char in unique_chars]), fignum=1, aspect='auto')
  # 
  # ax = plt.gca()
  # minor_locator = plt.MultipleLocator(2)
  # ax.xaxis.set_minor_locator(minor_locator)
  # plt.grid(which='minor')
  # 
  plt.xticks(np.arange(data.shape[1]), np.arange(data.shape[1]) + 1)
  plt.yticks(np.arange(data.shape[0]), np.arange(data.shape[0]) + 1)
  
  # Set ticks on both sides of axes on
  plt.tick_params(axis="x", bottom=True, top=False, labelbottom=True, labeltop=False)
  plt.yticks([0,1,2,3,4], ratio)

  plt.ylabel(behavior + ' per week', fontsize = 15) # y-axis label with fontsize 15
  # plt.title(strategy_name + ' \n Learning Strategy', loc='left', fontsize = 20)
  # custom legend
  reading_patch = mpatches.Patch(color='blue', label = 'nan')
  highlight_patch = mpatches.Patch(color='powderblue', label = 'low')
  notetake_patch = mpatches.Patch(color='tomato', label = 'high')
  plt.rc('xtick', labelsize=40)    # fontsize of the tick labels
  plt.rc('ytick', labelsize=40)    # fontsize of the tick labels
  # plt.legend(handles=[reading_patch, highlight_patch, notetake_patch], loc='upper left', bbox_to_anchor=(1.04, 1))
  plt.show()

# %%
sequences = reading0_input.to_numpy().tolist()
ratio = reading0.iloc[:, -1]
print(ratio)
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'reReading', 'reading', ratio)
# 少描述性統計()
# Out:
# cluster
# 2     54
# 3     60
# 4     60
# 1     65
# 0    221
# Name: count, dtype: int64
# reReading

# %%
sequences = reading1_input.to_numpy().tolist()
ratio = reading1.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'Reading&Highlight', 'reading', ratio)
# Out:
# Reading&Highlight

# %%
sequences = highlight0_input.to_numpy().tolist()
ratio = highlight0.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'reReading', 'highlight', ratio)
# Out:
# reReading

# %%
sequences = highlight1_input.to_numpy().tolist()
ratio = highlight1.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'Reading&Highlight', 'highlight', ratio)
# Out:
# Reading&Highlight

# %%
sequences = notetaking0_input.to_numpy().tolist()
ratio = notetaking0.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'reReading', 'notetaking', ratio)
# Out:
# reReading

# %%
sequences = notetaking1_input.to_numpy().tolist()
ratio = notetaking1.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'Reading&Highlight', 'notetaking', ratio)
# Out:
# Reading&Highlight

# %% [markdown]
# ## viscode

# %% [markdown]
# ### draw event per week

# %%
# !gdown 12RnZkiqEMu9Sq-uAfsTJaHPMoiAm2tV6
import pandas as pd
df = pd.read_csv("LBLS_seqs_input_data.csv")
df = df.fillna('')
# df = df[df['0'] != 'empty']
df = df.replace('empty', 'notebook_open')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12RnZkiqEMu9Sq-uAfsTJaHPMoiAm2tV6
# To: /content/LBLS_seqs_input_data.csv
# 100% 22.4M/22.4M [00:00<00:00, 145MB/s]
# ...

# %%
def vs_strategy_calculate(df, strategy_class):
  print('viscode class '+ str(strategy_class))
  df_tmp = df[df['class'] == strategy_class]
  df_tmp = df_tmp.drop(columns=['class'])
  df_tmp = df_tmp.reset_index(drop=True)
  df_tmp['notebook_open'] = 0
  df_tmp['code_speed'] = 0
  df_tmp['copy_paste'] = 0
  df_tmp['Execution'] = 0
  from collections import Counter
  # 統計seuqnce中行為
  for index, row in df_tmp.iterrows():
    values = Counter(row[2:])
    df_tmp.at[index, 'notebook_open'] = values['notebook_open']
    df_tmp.at[index, 'code_speed'] = values['code_speed']
    df_tmp.at[index, 'copy_paste'] = values['copy_paste']
    df_tmp.at[index, 'Execution'] = values['Execution']

  df_tmp = df_tmp[['username', 'weeks', 'notebook_open', 'code_speed', 'copy_paste', 'Execution']]

  # 由於有些learning strategy中少了學生部分行為週次的資料(也許他沒做，也許在另外一個strategy)，因此這邊補0
  for user in set(df_tmp['username']):
    for w in range(1,17):
      # 該週學生沒有learning strategy的行為就補0
      if w not in set(df_tmp[df_tmp['username'] == user]['weeks']):
        # 這裡邏輯好像有錯誤
        data = pd.DataFrame([[user, w, 0, 0, 0, 0]], columns=['username', 'weeks', 'notebook_open', 'code_speed', 'copy_paste', 'Execution'])
        # data = pd.DataFrame(columns=['username', 'weeks', 'notebook_open', 'code_speed', 'copy_paste', 'Execution'])
        df_tmp = pd.concat([df_tmp, data], ignore_index=True)
  df_tmp = df_tmp.sort_values(by=['username', 'weeks'])
  df_tmp = df_tmp.reset_index(drop=True)

  # bookroll0 reading、highlight、notetaking initialize
  notebook_open = pd.DataFrame(columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"])
  code_speed = pd.DataFrame(columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"])
  copy_paste = pd.DataFrame(columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"])
  Execution = pd.DataFrame(columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"])

  for user in set(df_tmp['username']):
    # data
    notebook_open_data = []
    code_speed_data = []
    copy_paste_data = []
    Execution_data = []
    notebook_open_data.append(str(user))
    code_speed_data.append(str(user))
    copy_paste_data.append(str(user))
    Execution_data.append(str(user))

    for w in range(1,17):
      tmp = df_tmp[(df_tmp['username'] == user) & (df_tmp['weeks'] == w)]
      notebook_open_data.append(tmp['notebook_open'].iloc[0])
      code_speed_data.append(tmp['code_speed'].iloc[0])
      copy_paste_data.append(tmp['copy_paste'].iloc[0])
      Execution_data.append(tmp['Execution'].iloc[0])
    # 將data放入dataframe
    notebook_open = pd.concat([notebook_open, pd.DataFrame([notebook_open_data], columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"]) ])
    code_speed = pd.concat([code_speed, pd.DataFrame([code_speed_data], columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"]) ])
    copy_paste = pd.concat([copy_paste, pd.DataFrame([copy_paste_data], columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"]) ])
    Execution = pd.concat([Execution, pd.DataFrame([Execution_data], columns=["username", "weeks1", "weeks2", "weeks3", "weeks4", "weeks5", "weeks6", "weeks7", "weeks8",
                      "weeks9", "weeks10", "weeks11", "weeks12", "weeks13", "weeks14", "weeks15", "weeks16"]) ])


  # 分組序列notebook_open，從中找代表序列，並算出代表序列的次數
  from sklearn.cluster import KMeans
  from collections import Counter
  kmeans = KMeans(n_clusters=5).fit(notebook_open.iloc[:,1:])
  centroids = kmeans.cluster_centers_
  predict = kmeans.predict(notebook_open.iloc[:,1:])

  notebook_open['cluster'] = predict
  # notebook_open.iloc[:,1:].head()
  # 之後要做mean，這邊把0作為nan讓他不會計算mean的時候考慮進去
  # reading = notebook_open.replace(0, np.nan)
  group_count = notebook_open['cluster'].value_counts()
  notebook_open = notebook_open.groupby(['cluster']).mean()
  notebook_open['count'] = group_count.sort_index()


  # 分組序列code_speed，從中找代表序列，並算出代表序列的次數
  from sklearn.cluster import KMeans
  from collections import Counter
  kmeans = KMeans(n_clusters=5).fit(code_speed.iloc[:,1:])
  centroids = kmeans.cluster_centers_
  predict = kmeans.predict(code_speed.iloc[:,1:])

  code_speed['cluster'] = predict
  # reading1.iloc[:,1:].head()
  # 之後要做mean，這邊把0作為nan讓他不會計算mean的時候考慮進去
  # highlight = highlight.replace(0, np.nan)
  group_count = code_speed['cluster'].value_counts()
  code_speed = code_speed.groupby(['cluster']).mean()
  code_speed['count'] = group_count.sort_index()



  # 分組序列copy_paste，從中找代表序列，並算出代表序列的次數
  from sklearn.cluster import KMeans
  from collections import Counter
  kmeans = KMeans(n_clusters=5).fit(copy_paste.iloc[:,1:])
  centroids = kmeans.cluster_centers_
  predict = kmeans.predict(copy_paste.iloc[:,1:])

  copy_paste['cluster'] = predict
  # reading1.iloc[:,1:].head()
  # 之後要做mean，這邊把0作為nan讓他不會計算mean的時候考慮進去
  # notetaking = notetaking.replace(0, np.nan)
  group_count = copy_paste['cluster'].value_counts()
  copy_paste = copy_paste.groupby(['cluster']).mean()
  copy_paste['count'] = group_count.sort_index()

  # 分組序列Execution，從中找代表序列，並算出代表序列的次數
  from sklearn.cluster import KMeans
  from collections import Counter
  kmeans = KMeans(n_clusters=5).fit(Execution.iloc[:,1:])
  centroids = kmeans.cluster_centers_
  predict = kmeans.predict(Execution.iloc[:,1:])

  Execution['cluster'] = predict
  # reading1.iloc[:,1:].head()
  # 之後要做mean，這邊把0作為nan讓他不會計算mean的時候考慮進去
  # notetaking = notetaking.replace(0, np.nan)
  group_count = Execution['cluster'].value_counts()
  Execution = Execution.groupby(['cluster']).mean()
  Execution['count'] = group_count.sort_index()


  return notebook_open, code_speed, copy_paste, Execution

# %%
notebook_open0, code_speed0, copy_paste0, Execution0 = vs_strategy_calculate(df, 0)
notebook_open0 = notebook_open0.sort_values(['count'])
code_speed0 = code_speed0.sort_values(['count'])
copy_paste0 = copy_paste0.sort_values(['count'])
Execution0 = Execution0.sort_values(['count'])
notebook_open1, code_speed1, copy_paste1, Execution1 = vs_strategy_calculate(df, 1)
notebook_open1 = notebook_open1.sort_values(['count'])
code_speed1 = code_speed1.sort_values(['count'])
copy_paste1 = copy_paste1.sort_values(['count'])
Execution1 = Execution1.sort_values(['count'])
# Out:
# viscode class 0
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# viscode class 1
# ...

# %% [markdown]
# ### 透過average去分類 高低

# %%
import numpy as np
# 將兩個學習策略的dataframe合併起來算平均
notebook_open_all = pd.concat([ notebook_open0.iloc[:, 1: -1], notebook_open1.iloc[:, 1: -1] ])
notebook_open_all = notebook_open_all.to_numpy().flatten().astype(int)
notebook_open_all = notebook_open_all[notebook_open_all != 0]
notebook_open_all_mean = round(notebook_open_all.mean(), 0)

code_speed_all = pd.concat([ code_speed0.iloc[:, 1: -1], code_speed1.iloc[:, 1: -1] ])
code_speed_all = code_speed_all.to_numpy().flatten().astype(int)
code_speed_all = code_speed_all[code_speed_all != 0]
code_speed_all_mean = round(code_speed_all.mean(), 0)

copy_paste_all = pd.concat([ copy_paste0.iloc[:, 1: -1], copy_paste1.iloc[:, 1: -1] ])
copy_paste_all = copy_paste_all.to_numpy().flatten().astype(int)
copy_paste_all = copy_paste_all[copy_paste_all != 0]
copy_paste_all_mean = round(copy_paste_all.mean(), 0)

Execution_all = pd.concat([ Execution0.iloc[:, 1: -1], Execution1.iloc[:, 1: -1] ])
Execution_all = Execution_all.to_numpy().flatten().astype(int)
Execution_all = Execution_all[Execution_all != 0]
Execution_all_mean = round(Execution_all.mean(), 0)

# %%
notebook_open0_input = notebook_open0.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > notebook_open_all_mean else 'low'))
code_speed0_input = code_speed0.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > code_speed_all_mean else 'low'))
copy_paste0_input = copy_paste0.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > copy_paste_all_mean else 'low'))
Execution0_input = Execution0.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > Execution_all_mean else 'low'))

notebook_open1_input = notebook_open1.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > notebook_open_all_mean else 'low'))
code_speed1_input = code_speed1.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > code_speed_all_mean else 'low'))
copy_paste1_input = copy_paste1.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > copy_paste_all_mean else 'low'))
Execution1_input = Execution1.iloc[:, 1: -1].applymap(lambda x: 'empty' if x < 1 else ('high' if x > Execution_all_mean else 'low'))

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
import matplotlib.patches as mpatches

def draw(sequences, strategy_name, behavior, ratio):
  print(strategy_name)
  data = sequences
  data = np.array(data)
  unique_chars, matrix = np.unique(data, return_inverse=True)
  color_dict = {'empty': 'blue', 'low': 'powderblue', 'high': 'tomato'}

  # 圖片顯示大小、顏色、matrix代表資料
  plt.figure(figsize=(12,10))
  plt.matshow(matrix.reshape(data.shape), cmap=ListedColormap([color_dict[char] for char in unique_chars]), fignum=1, aspect='auto')

  plt.xticks(np.arange(data.shape[1]), np.arange(data.shape[1]) + 1)
  plt.yticks(np.arange(data.shape[0]), np.arange(data.shape[0]) + 1)
  # plt.xaxis.set_major_formatter(formatter)

  # Set ticks on both sides of axes on
  plt.tick_params(axis="x", bottom=True, top=False, labelbottom=True, labeltop=False)
  plt.yticks([0,1,2,3,4], ratio)

  plt.ylabel(behavior + ' per week', fontsize = 15) # y-axis label with fontsize 15
  # plt.title(strategy_name + ' \n Learning Strategy', loc='left', fontsize = 20)
  plt.rc('xtick', labelsize=40)    # fontsize of the tick labels
  plt.rc('ytick', labelsize=40)    # fontsize of the tick labels
  # custom legend
  reading_patch = mpatches.Patch(color='blue', label = 'nan')
  highlight_patch = mpatches.Patch(color='powderblue', label = 'low')
  notetake_patch = mpatches.Patch(color='tomato', label = 'high')
  # plt.legend(handles=[reading_patch, highlight_patch, notetake_patch], loc='upper left', bbox_to_anchor=(1.04, 1))
  plt.show()

# %%
sequences = notebook_open0_input.to_numpy().tolist()
ratio = notebook_open0.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'Surface approach', 'notebook_open', ratio)
# Out:
# Surface approach

# %%
sequences = notebook_open1_input.to_numpy().tolist()
ratio = notebook_open1.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'Deep approach', 'notebook_open', ratio)
# Out:
# Deep approach

# %%
sequences = code_speed0_input.to_numpy().tolist()
ratio = code_speed0.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'Surface approach', 'code_speed', ratio)
# Out:
# Surface approach

# %%
sequences = code_speed1_input.to_numpy().tolist()
ratio = code_speed1.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'Deep approach', 'code_speed', ratio)
# Out:
# Deep approach

# %%
sequences = copy_paste0_input.to_numpy().tolist()
ratio = copy_paste0.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'Surface approach', 'copy_paste', ratio)
# Out:
# Surface approach

# %%
sequences = copy_paste1_input.to_numpy().tolist()
ratio = copy_paste1.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'Deep approach', 'copy_paste', ratio)
# Out:
# Deep approach

# %%
sequences = Execution0_input.to_numpy().tolist()
ratio = Execution0.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'Surface approach', 'Execution', ratio)
# Out:
# Surface approach

# %%
sequences = Execution1_input.to_numpy().tolist()
ratio = Execution1.iloc[:, -1]
ratio = [str(int(item*100)) + "%" for item in round(ratio/sum(ratio), 2)]
draw(sequences, 'Deep approach', 'Execution', ratio)
# Out:
# Deep approach
